# %%
import pandas as pd

# %%
dataset=pd.read_csv("covid19.csv")

# %%
dataset
# Out:
#      Sno      Date State/UnionTerritory  ConfirmedIndianNational  \
# 0      1  30/01/20               Kerala                        1
# 1      2  31/01/20               Kerala                        1
# 2      3  01/02/20               Kerala                        2
# 3      4  02/02/20               Kerala                        3
# 4      5  03/02/20               Kerala                        3
# ..   ...       ...                  ...                      ...
# 265  266  21/03/20    Jammu and Kashmir                        4
# 266  267  21/03/20               Ladakh                       13
# 267  268  21/03/20        Uttar Pradesh                       23
# 268  269  21/03/20          Uttarakhand                        3
# 269  270  21/03/20          West Bengal                        3
#
#      ConfirmedForeignNational  Cured  Deaths
# 0                           0      0       0
# 1                           0      0       0
# 2                           0      0       0
# ...

# %%
import numpy as np

# %%
dataset2=dataset.groupby(by="Date",sort=False)[['ConfirmedIndianNational','ConfirmedForeignNational','Cured','Deaths']].sum()

# %%
dataset2
# Out:
#           ConfirmedIndianNational  ConfirmedForeignNational  Cured  Deaths
# Date
# 30/01/20                        1                         0      0       0
# 31/01/20                        1                         0      0       0
# 01/02/20                        2                         0      0       0
# 02/02/20                        3                         0      0       0
# 03/02/20                        3                         0      0       0
# 04/02/20                        3                         0      0       0
# 05/02/20                        3                         0      0       0
# 06/02/20                        3                         0      0       0
# 07/02/20                        3                         0      0       0
# 08/02/20                        3                         0      0       0
# 09/02/20                        3                         0      0       0
# ...

# %%
total=dataset2.sum(axis=1)

# %%
total
# Out:
# Date
# 30/01/20      1
# 31/01/20      1
# 01/02/20      2
# 02/02/20      3
# 03/02/20      3
# 04/02/20      3
# 05/02/20      3
# 06/02/20      3
# 07/02/20      3
# 08/02/20      3
# 09/02/20      3
# 10/02/20      3
# 11/02/20      3
# 12/02/20      3
# 13/02/20      3
# 14/02/20      3
# 15/02/20      3
# 16/02/20      3
# 17/02/20      3
# 18/02/20      3
# 19/02/20      3
# 20/02/20      3
# 21/02/20      3
# 22/02/20      3
# 23/02/20      3
# 24/02/20      3
# 25/02/20      3
# 26/02/20      3
# 27/02/20      3
# 28/02/20      3
# 29/02/20      3
# 01/03/20      3
# 02/03/20      5
# 03/03/20      9
# 04/03/20     31
# 05/03/20     33
# 06/03/20     34
# 07/03/20     37
# 08/03/20     42
# 09/03/20     49
# 10/03/20     61
# 11/03/20     63
# 12/03/20     77
# 13/03/20     85
# 14/03/20     96
# 15/03/20    125
# 16/03/20    129
# 17/03/20    154
# 18/03/20    168
# 19/03/20    197
# 20/03/20    250
# 21/03/20    310
# dtype: int64

# %%
total.plot(kind='bar')
